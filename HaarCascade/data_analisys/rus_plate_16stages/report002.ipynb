# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load the CSV file
df = pd.read_csv("csvs/results_22655.csv")

# %%
df.head(15)
# Out:
#                     file    type dataset  detected_count    time_ns  first_x  \
# 0            1187019.jpg  Brazil     DS1               1  159007700     2352
# 1   1187019_labelled.jpg  Brazil     DS1               1  133052000     1988
# 2            1792023.jpg  Brazil     DS1               1  112468300     1532
# 3   1792023_labelled.jpg  Brazil     DS1               1  131016500     1532
# 4            2114000.jpg  Brazil     DS1               4   99442600     1409
# 5   2114000_labelled.jpg  Brazil     DS1               3  103517700     2222
# 6            2148000.jpg  Brazil     DS1               0  112070600        0
# 7   2148000_labelled.jpg  Brazil     DS1               1  109392900     1470
# 8            2154018.jpg  Brazil     DS1               0  109080700        0
# 9   2154018_labelled.jpg  Brazil     DS1               1  103890100      994
# 10           2601032.jpg  Brazil     DS1               2  118645400     2303
# ...
