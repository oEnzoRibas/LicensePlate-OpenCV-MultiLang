# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load the CSV files
df1 = pd.read_csv("csvs/results_26583.csv")
df2 = pd.read_csv("csvs/results_90106.csv")
df3 = pd.read_csv("csvs/results_95218.csv")

df = pd.concat([df1, df2, df3], ignore_index=True)

# %%
df.head(15)
# Out:
#                     file    type dataset  detected_count    time_ns  first_x  \
# 0            1187019.jpg  Brazil     DS1               4  531013500     2126
# 1   1187019_labelled.jpg  Brazil     DS1               5  212296400     2126
# 2            1792023.jpg  Brazil     DS1               2  197060000     3245
# 3   1792023_labelled.jpg  Brazil     DS1               2  247523300     3245
# 4            2114000.jpg  Brazil     DS1              10  187191700     1872
# 5   2114000_labelled.jpg  Brazil     DS1               7  181491200     1872
# 6            2148000.jpg  Brazil     DS1               8  186418800     1727
# 7   2148000_labelled.jpg  Brazil     DS1               8  182809500     1866
# 8            2154018.jpg  Brazil     DS1               4  195412800       89
# 9   2154018_labelled.jpg  Brazil     DS1               3  200433300       96
# 10           2601032.jpg  Brazil     DS1               9  174868300     1667
# ...
